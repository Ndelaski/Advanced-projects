# %% [markdown]
# <h1 style="text-align: center;">
#     Predicting COVID using Bayesian Networks </br>
#     INFO 7016 Postgraduate Project A
# </h1>
# <h2 style="text-align: center;">
#     Autumn 2023</br>
#     Weekly Diary <br>
# </h2>
#
# <h4 style="text-align: center;">
#     Andrew Opata </br>
#     Christine Pascual </br>
# </h4>
# <p style="text-align: justify;">
#     The main scope of the project is to improve the accuracy of diagnosing Long COVID-19 using Bayesian
# Networks. The project aims to reproduce and enhance the results of a previous study (DOI: https://doi.org/10.1101/2020.10.22.20217554) that used
# Bayesian Networks for diagnosing COVID-19. Additionally, the project aims to test the
# performance of the Bayesian Network model on patient data from a hospital in Sydney.
# </p>

# %% [markdown]
# ## Week1 06/03/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week2 13/03/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week3 20/03/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week4 27/03/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week5 03/04/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week6 10/04/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week7 17/04/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week8 24/04/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week9 01/05/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week10 08/05/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week11 15/05/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week12 22/05/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week13 29/05/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week14 05/06/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week15 12/06/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week16 19/06/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# ## Week17 26/06/2023

# %% [markdown]
# #### General

# %% [markdown]
# #### Christine
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Andrew
#
# Reading based on: https://doi.org/10.1101/2020.10.22.20217554

# %% [markdown]
# #### Appendix

# %% [markdown]
# lorem ipsum

# %% [markdown]
# ## Bibliography
# <div class="cite2c-biblio"></div>

# %% [markdown]
# See {cite:p}`butcher2020extending` for an introduction to non-standard analysis.
#
# ```{bibliography} references.bib
# ```
#
#
# ```{bibliography} path/to/references.bib
# :style: unsrt
# ```
